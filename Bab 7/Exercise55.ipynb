# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install chart_studio
# Out:
# Collecting chart_studio
#   Downloading chart_studio-1.1.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from chart_studio) (5.24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from chart_studio) (2.32.4)
# Collecting retrying>=1.3.3 (from chart_studio)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from chart_studio) (1.17.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->chart_studio) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly->chart_studio) (25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->chart_studio) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->chart_studio) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->chart_studio) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->chart_studio) (2025.10.5)
# Downloading chart_studio-1.1.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 2.5 MB/s eta 0:00:00
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Installing collected packages: retrying, chart_studio
# Successfully installed chart_studio-1.1.0 retrying-1.4.2

# %%
import pandas as pd
import plotly.express as px
import numpy as np
import chart_studio.plotly as py
import plotly.graph_objs as go

# %%
co2 = pd.read_csv('/content/drive/MyDrive/Visualisasi Informasi/Interactive-Data-Visualization-with-Python/datasets/co2.csv')
gm = pd.read_csv('/content/drive/MyDrive/Visualisasi Informasi/Interactive-Data-Visualization-with-Python/datasets/gapminder.csv')

# %%
df_gm = gm[['Country', 'region']].drop_duplicates()
df_w_regions = pd.merge(co2, df_gm, left_on='country', right_on='Country', how='inner')
df_w_regions = df_w_regions.drop('Country', axis='columns')

# %%
new_co2 = pd.melt(df_w_regions, id_vars=['country', 'region'])
columns = ['country', 'region', 'year', 'co2']
new_co2.columns = columns
df_co2 = new_co2[new_co2['year'].astype('int64') > 1963]
df_co2 = df_co2.sort_values(by=['country', 'year'])
df_co2['year'] = df_co2['year'].astype('int64')
df_g = gm[['Country', 'Year', 'gdp', 'population', 'fertility', 'life']]
df_g.columns = ['country', 'year', 'gdp', 'population', 'fertility', 'life']
data = pd.merge(df_co2, df_g, on=['country', 'year'], how='left')
data = data.dropna()

# %%
source = [
 go.Bar(x = data['region'],
 y = data.co2[data['year'] == 1970]),
 go.Bar(x = data['region'],
 y = data.co2[data['year'] == 1980]),
 go.Bar(x = data['region'],
 y = data.co2[data['year'] == 1990]),
 go.Bar(x = data['region'],
 y = data.co2[data['year'] == 2000]),
 go.Bar(x = data['region'],
 y = data.co2[data['year'] == 2010]),
]

# %%
layout = go.Layout(barmode = 'stack')

# %%
fig = go.Figure(source, layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d091c0db-7f9b-4e5d-b50a-45c0641a0eab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d091c0db-7f9b-4e5d-b50a-45c0641a0eab")) {                    Plotly.newPlot(                        "d091c0db-7f9b-4e5d-b50a-45c0641a0eab",                        [{"x":["South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","South Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Europe & Central Asia","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Middle East & North Africa","Sub-Saharan Africa","Sub-Saharan Africa","Sub-Saharan Africa","Sub-Saharan Africa","Sub-Saharan Africa","Sub-Saharan Africa","Sub ...
