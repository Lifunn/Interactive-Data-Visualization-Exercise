# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import plotly.express as px
import numpy as np

# %%
co2 = pd.read_csv("/content/drive/MyDrive/Visualisasi Informasi/Interactive-Data-Visualization-with-Python/datasets/co2.csv")
co2.head()
# Out:
#        country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0  Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1      Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2      Algeria   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3      Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4       Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#      2005    2006    2007   2008   2009   2010   2011  2012   2013   2014
# 0  0.0529  0.0637  0.0854  0.154  0.242  0.294  0.412  0.35  0.316  0.299
# 1  1.3800  1.2800  1.3000  1.460  1.480  1.560  1.790  1.68  1.730  1.960
# 2  3.2200  2.9900  3.1900  3.160  3.420  3.300  3.290  3.46  3.510  3.720
# 3  7.3000  6.7500  6.5200  6.430  6.120  6.120  5.870  5.92  5.900  5.830
# 4  0.9800  1.1000  1.2000  1.180  1.230  1.240  1.250  1.33  1.250  1.290
#
# [5 rows x 216 columns]

# %%
co2.columns
# Out:
# Index(['country', '1800', '1801', '1802', '1803', '1804', '1805', '1806',
#        '1807', '1808',
#        ...
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014'],
#       dtype='object', length=216)

# %%
co2_long = co2.melt(id_vars=["country"], var_name="year", value_name="co2")
co2_long.head()
# Out:
#        country  year  co2
# 0  Afghanistan  1800  NaN
# 1      Albania  1800  NaN
# 2      Algeria  1800  NaN
# 3      Andorra  1800  NaN
# 4       Angola  1800  NaN

# %%
co2_long["year"] = co2_long["year"].astype(int)

# %%
gm = pd.read_csv("/content/drive/MyDrive/Visualisasi Informasi/Interactive-Data-Visualization-with-Python/datasets/gapminder.csv")
gm.head()
# Out:
#        Country  Year  fertility    life  population  child_mortality     gdp  \
# 0  Afghanistan  1964      7.671  33.639  10474903.0            339.7  1182.0
# 1  Afghanistan  1965      7.671  34.152  10697983.0            334.1  1182.0
# 2  Afghanistan  1966      7.671  34.662  10927724.0            328.7  1168.0
# 3  Afghanistan  1967      7.671  35.170  11163656.0            323.3  1173.0
# 4  Afghanistan  1968      7.671  35.674  11411022.0            318.1  1187.0
#
#        region
# 0  South Asia
# 1  South Asia
# 2  South Asia
# 3  South Asia
# 4  South Asia

# %%
gm.columns = gm.columns.str.strip().str.lower()
co2.columns = co2.columns.str.strip().str.lower()

# %%
gm = gm.merge(co2_long, on=["country", "year"], how="left")
gm.head()
# Out:
#        country  year  fertility    life  population  child_mortality     gdp  \
# 0  Afghanistan  1964      7.671  33.639  10474903.0            339.7  1182.0
# 1  Afghanistan  1965      7.671  34.152  10697983.0            334.1  1182.0
# 2  Afghanistan  1966      7.671  34.662  10927724.0            328.7  1168.0
# 3  Afghanistan  1967      7.671  35.170  11163656.0            323.3  1173.0
# 4  Afghanistan  1968      7.671  35.674  11411022.0            318.1  1187.0
#
#        region   co2_x   co2_y
# 0  South Asia  0.0863  0.0863
# 1  South Asia  0.1010  0.1010
# 2  South Asia  0.1080  0.1080
# 3  South Asia  0.1240  0.1240
# 4  South Asia  0.1160  0.1160

# %%
print("Kolom setelah merge:", gm.columns.tolist())
# Out:
# Kolom setelah merge: ['country', 'year', 'fertility', 'life', 'population', 'child_mortality', 'gdp', 'region', 'co2_x', 'co2_y']

# %%
gm["co2"] = gm["co2_y"].combine_first(gm["co2_x"])
gm = gm.drop(columns=["co2_x", "co2_y"], errors="ignore")

# %%
gm.head()
# Out:
#        country  year  fertility    life  population  child_mortality     gdp  \
# 0  Afghanistan  1964      7.671  33.639  10474903.0            339.7  1182.0
# 1  Afghanistan  1965      7.671  34.152  10697983.0            334.1  1182.0
# 2  Afghanistan  1966      7.671  34.662  10927724.0            328.7  1168.0
# 3  Afghanistan  1967      7.671  35.170  11163656.0            323.3  1173.0
# 4  Afghanistan  1968      7.671  35.674  11411022.0            318.1  1187.0
#
#        region     co2
# 0  South Asia  0.0863
# 1  South Asia  0.1010
# 2  South Asia  0.1080
# 3  South Asia  0.1240
# 4  South Asia  0.1160

# %%
# Ganti nilai kosong agar plotly tidak error
gm["population"] = gm["population"].fillna(gm["population"].median())

# %%
fig_life = px.scatter(
    gm,
    x="life",
    y="co2",
    animation_frame="year",
    animation_group="country",
    size="population",
    color="region",
    hover_name="country",
    size_max=60,
    range_x=[25, 85],
    range_y=[0, gm["co2"].max() * 1.05 if gm["co2"].notna().any() else 10],
    title="After Step 4: CO2 vs Life Expectancy"
)
fig_life.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d839296a-c67d-4c47-ad02-9a8a47da55fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d839296a-c67d-4c47-ad02-9a8a47da55fb")) {                    Plotly.newPlot(                        "d839296a-c67d-4c47-ad02-9a8a47da55fb",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eregion=South Asia\u003cbr\u003eyear=1964\u003cbr\u003elife=%{x}\u003cbr\u003eco2=%{y}\u003cbr\u003epopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Bangladesh","Bhutan","India","Maldives","Nepal","Pakistan","Sri Lanka"],"ids":["Afghanistan","Bangladesh","Bhutan","India","Maldives","Nepal","Pakistan","Sri Lanka"],"legendgroup":"South Asia","marker":{"color":"#636efa","size":[10474903.0,56071080.0,251419.0,486038945.0,100370.0,10495972.0,50678979.0,10962237.0],"sizemode":"area","sizeref":377602.35277777776,"symbol":"circle"},"mode":"markers","name":"South Asia","orientation":"v","showlegend":true,"x":[33.639,49.297,33.827,44.375,38.911,40.071,49.807,61.09],"xaxis":"x","y":[0.0863,0.055,null,0.309,null,0.014,0.324,0.21],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eregion=Europe & Central Asia\u003cbr\u003eyear=1964\u003cbr\u003elife=%{x}\u003cbr\u003eco2=%{y}\u003cbr\u003epopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Albania","Armenia","Austria","Azerbaijan","Belarus","Belgium","Bosnia and Herzegovina","Bulgaria","Channel Islands","Croatia","Cyprus","Czech Rep.","Denmark","Estonia","Finland","France","Georgia","Germany","Greece","Greenland","Hungary","Iceland","Ireland","Italy","Kazakhstan","Kyrgyzstan","Latvia","Lithuania","Luxembourg","Macedonia, FYR","Malta","Moldova","Montenegro","Netherlands","Norway","Poland","Portugal","Romania","Russia","Serbia","Slovak Republic","Slovenia","Spain","Sweden","Switzerland","Tajikistan","Turkey","Turkmenistan","Ukraine","United Kingdom","Uzbekistan"],"ids":["Albania","Armenia","Austria","Azerbaijan","Belarus","Belgium","Bosnia and Herzegovina","Bulgaria","Channel Islands","Croatia","Cyprus","Czech Rep.","Denmark","Estonia","Finland","France","Georgia","Germany","Greece","Greenland","Hungary","Iceland","Ireland","Italy","Kazakhstan","Kyrgyzstan","Latvia","Lithuania","Luxembourg","Macedonia, FYR","Malta","Moldova","Montenegro","Netherlands","Norway","Poland","Portugal","Romania","Russia","Serbia","Slovak Republic","Slovenia","Spain","Sweden","Switzerland","Tajikistan","Turkey","Turkmenistan","Ukraine","United Kingdom","Uzbekistan"],"legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","size":[1817098.0,2138133.0,7220812.0,4440733.0,8521413.0,9384939.0,3357005.0,8140705.0,113765.0,4108808.0,578710.0,9661235.0,4722383.0,1275487.0,4545748.0,48194218.0,4419666.0,75363329.0,8509724.0,37810.0,10107595.0,189148.0,2860976.0,51054762.0,11577537.0,2490244.0,2236535.0,2927610.0,328603.0,1462410.0,307119.0,3275331.0,500745.0,12055386.0,3693750.0,30740557.0,8925792.0,18870340.0,125644787.0,7831873.0,4302571.0,1621265.0,31764645.0,7676568.0,5729362.0,2424189.0,31109820.0,1829697.0,44868657.0,54006245.0,9888629.0],"sizemode":"area","sizeref":377602.35277777776,"symbol":"circle"},"mode":"markers","name":"Europe & Central Asia","orientation":"v","showlegend":true,"x":[65.475,67.714,70.16,62.701,73.48,70.73,62.81399999999999,71.14,71.143,66.3,70.895,70.58,72.52,70.64,69.37,71.32,65.293,70.6511001188,69.493,63.2365350004,69.48,73.57,70.49,70.4,60.196000000000005,58.055,71.55,71.94,69.07,63.06,68.839,63.496,66.411,73.73,73.61,68.8,65.24,67.73,69.85,65.05,71.09,69.197,70.58,73.73,72.2,57.84,48.313,56.181,72. ...

# %%
corr_life = gm[["co2", "life"]].corr().iloc[0, 1]
print("Correlation between CO2 and Life:", round(corr_life, 3))
# Out:
# Correlation between CO2 and Life: 0.403

# %%
fig_fertility = px.scatter(
    gm,
    x="fertility",
    y="co2",
    animation_frame="year",
    animation_group="country",
    size="population",
    color="region",
    hover_name="country",
    size_max=60,
    range_x=[1, 9],
    range_y=[0, gm["co2"].max() * 1.05 if gm["co2"].notna().any() else 10],
    title="After Step 5: CO2 vs Fertility"
)
fig_fertility.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fed1a1c4-e3be-48b0-9d0e-9ffda7b96591" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fed1a1c4-e3be-48b0-9d0e-9ffda7b96591")) {                    Plotly.newPlot(                        "fed1a1c4-e3be-48b0-9d0e-9ffda7b96591",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eregion=South Asia\u003cbr\u003eyear=1964\u003cbr\u003efertility=%{x}\u003cbr\u003eco2=%{y}\u003cbr\u003epopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Bangladesh","Bhutan","India","Maldives","Nepal","Pakistan","Sri Lanka"],"ids":["Afghanistan","Bangladesh","Bhutan","India","Maldives","Nepal","Pakistan","Sri Lanka"],"legendgroup":"South Asia","marker":{"color":"#636efa","size":[10474903.0,56071080.0,251419.0,486038945.0,100370.0,10495972.0,50678979.0,10962237.0],"sizemode":"area","sizeref":377602.35277777776,"symbol":"circle"},"mode":"markers","name":"South Asia","orientation":"v","showlegend":true,"x":[7.671,6.853,6.67,5.807,7.178999999999999,5.997000000000001,6.6,5.067],"xaxis":"x","y":[0.0863,0.055,null,0.309,null,0.014,0.324,0.21],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eregion=Europe & Central Asia\u003cbr\u003eyear=1964\u003cbr\u003efertility=%{x}\u003cbr\u003eco2=%{y}\u003cbr\u003epopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Albania","Armenia","Austria","Azerbaijan","Belarus","Belgium","Bosnia and Herzegovina","Bulgaria","Channel Islands","Croatia","Cyprus","Czech Rep.","Denmark","Estonia","Finland","France","Georgia","Germany","Greece","Greenland","Hungary","Iceland","Ireland","Italy","Kazakhstan","Kyrgyzstan","Latvia","Lithuania","Luxembourg","Macedonia, FYR","Malta","Moldova","Montenegro","Netherlands","Norway","Poland","Portugal","Romania","Russia","Serbia","Slovak Republic","Slovenia","Spain","Sweden","Switzerland","Tajikistan","Turkey","Turkmenistan","Ukraine","United Kingdom","Uzbekistan"],"ids":["Albania","Armenia","Austria","Azerbaijan","Belarus","Belgium","Bosnia and Herzegovina","Bulgaria","Channel Islands","Croatia","Cyprus","Czech Rep.","Denmark","Estonia","Finland","France","Georgia","Germany","Greece","Greenland","Hungary","Iceland","Ireland","Italy","Kazakhstan","Kyrgyzstan","Latvia","Lithuania","Luxembourg","Macedonia, FYR","Malta","Moldova","Montenegro","Netherlands","Norway","Poland","Portugal","Romania","Russia","Serbia","Slovak Republic","Slovenia","Spain","Sweden","Switzerland","Tajikistan","Turkey","Turkmenistan","Ukraine","United Kingdom","Uzbekistan"],"legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","size":[1817098.0,2138133.0,7220812.0,4440733.0,8521413.0,9384939.0,3357005.0,8140705.0,113765.0,4108808.0,578710.0,9661235.0,4722383.0,1275487.0,4545748.0,48194218.0,4419666.0,75363329.0,8509724.0,37810.0,10107595.0,189148.0,2860976.0,51054762.0,11577537.0,2490244.0,2236535.0,2927610.0,328603.0,1462410.0,307119.0,3275331.0,500745.0,12055386.0,3693750.0,30740557.0,8925792.0,18870340.0,125644787.0,7831873.0,4302571.0,1621265.0,31764645.0,7676568.0,5729362.0,2424189.0,31109820.0,1829697.0,44868657.0,54006245.0,9888629.0],"sizemode":"area","sizeref":377602.35277777776,"symbol":"circle"},"mode":"markers","name":"Europe & Central Asia","orientation":"v","showlegend":true,"x":[5.711,4.1610000000000005,2.795,5.468,2.6010000000000004,2.599,3.619,2.181,2.551,2.211,3.249,2.123,2.602,1.953,2.58,2.8,2.864,2.494,2.259,7.27,1.876,3.736,3.987,2.5,4.2010000000000005,5.317,1.819,2.378,2.374,3.446,2.798,2.989,3.093,3.17,2.96,2.5,3.189,1.9469026549,2.16,2.517,2.779,2.34,2.826,2.475,2.564,6.433,6.029,6. ...

# %%
corr_fertility = gm[["co2", "fertility"]].corr().iloc[0, 1]
print("Correlation between CO2 and Fertility:", round(corr_fertility, 3))
# Out:
# Correlation between CO2 and Fertility: -0.314
