# %%
import pandas as pd
import numpy as np

# %%
passenger_df = pd.read_csv("D:\Download\Visualisasi Informasi\Self Learning\Interactive-Data-Visualization-with-Python\datasets\chap5_data\AirPassengersDates.csv")
passenger_df["Date"] = pd.to_datetime(passenger_df["Date"]) 
passenger_df.head()
# Out:
#         Date  #Passengers
# 0 1949-01-12          112
# 1 1949-02-24          118
# 2 1949-03-22          132
# 3 1949-04-05          129
# 4 1949-05-24          121

# %%
passenger_df["month"] = passenger_df["Date"].dt.month
passenger_df["day"] = passenger_df["Date"].dt.day
passenger_df["day_name"] = passenger_df["Date"].dt.day_name()

# %%
passenger_per_month = passenger_df.groupby(["month"])[["#Passengers"]].agg("sum") 
passenger_per_month = passenger_per_month.reset_index() 
passenger_per_month.head()
# Out:
#    month  #Passengers
# 0      1         2901
# 1      2         2820
# 2      3         3242
# 3      4         3205
# 4      5         3262

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\lenovo\anaconda3\envs\kecerdasankomputasional\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\lenovo\anaconda3\envs\kecerdasankomputasional\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\lenovo\anaconda3\envs\kecerdasankomputasional\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\lenovo\anaconda3\envs\kecerdasankomputasional\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\anaconda3\envs\kecerdasankomputasional\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\anaconda3\envs\kecerdasankomputasional\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\anaconda3\envs\kecerdasankomputasional\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lenovo\anaconda3\envs\kecerdasankomputasional\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\envs\kecerdasankomputasional\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lenovo\anaconda3\envs\kecerdasankomputasional\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\lenovo\anaconda3\envs\kecerdasankomputasional\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\anaconda3\envs\kecerdasankomputasional\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\lenovo\anaconda3\envs\kecerdasankomputasional\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\envs\kecerdasankomputasional\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lenovo\anaconda3\envs\kecerdasankomputasional\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\lenovo\anaconda3\envs\kecerdasankomputasional\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\envs\kecerdasankomputasional\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
plt.figure(figsize=(16,8))

# %%
ax = sns.barplot(x="month",y="#Passengers", data=passenger_per_month) 
ax.set_title("Bar Plot - Passengers per month")
#Annotate the bars with value to have better idea
for p, v in zip(ax.patches, passenger_per_month['#Passengers']): 
   height = p.get_height() 
   ax.text(p.get_x() + p.get_width() / 2, height + 5, v, ha='center', va='bottom') 
plt.show()

# %%
mean_passengers_per_month = passenger_df.groupby(["month"])[["#Passengers"]].agg("mean").reset_index()
mean_passengers_per_month.head()
# Out:
#    month  #Passengers
# 0      1   241.750000
# 1      2   235.000000
# 2      3   270.166667
# 3      4   267.083333
# 4      5   271.833333

# %%
median_passengers_per_month = passenger_df.groupby(["month"])[["#Passengers"]].agg("median").reset_index()
median_passengers_per_month.head()
# Out:
#    month  #Passengers
# 0      1        223.0
# 1      2        214.5
# 2      3        251.5
# 3      4        252.0
# 4      5        252.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))

# %%
ax = sns.lineplot(x="month",y="#Passengers", data=passenger_df, 
ci=80)
ax.set_title("Bar Plot Mean and Standard Deviation per Month")
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_37868\2891624265.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 80)` for the same effect.
#
#   ax = sns.lineplot(x="month",y="#Passengers", data=passenger_df,
